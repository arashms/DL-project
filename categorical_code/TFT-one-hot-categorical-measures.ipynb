# %% [markdown]
# <a href="https://colab.research.google.com/github/arashms/DL-project/blob/DataPreparationForTFT/TFT-category.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pytorch_forecasting.data.examples import get_stallion_data
import pandas as pd
import torch
import numpy as np

import pytorch_lightning as pl
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks import (
    EarlyStopping,
    LearningRateMonitor
)

from pytorch_forecasting.metrics import QuantileLoss
from pytorch_forecasting.models import TemporalFusionTransformer
from pytorch_forecasting.data import (
    TimeSeriesDataSet,
    GroupNormalizer
)
# %config Completer.use_jedi = False

# %%
# !ls
# Out:
# lightning_logs			  TFT-categorical-data.ipynb
# TFT-categorical-data-Copy1.ipynb  TFT-one-hot-categorical-measures.ipynb

# %%
# DATA_DIR = "/content/gdrive/MyDrive/DL-proj/"
DATA_FILE = "../../data.xlsx"
RANDOM_SEED = 754

MIN_PREDICTION_LENGTH = 1
MAX_PREDICTION_LENGTH = 14
MAX_ENCODER_LENGTH = 70
MIN_ENCODER_LENGTH = 1


BATCH_SIZE = 10

# %%
if torch.cuda.is_available():    
    device = torch.device("cuda")
    print('GPU available, using cuda.')
    torch.cuda.manual_seed_all(RANDOM_SEED) #for reproducablity
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# GPU available, using cuda.

# %%
xl_file = pd.ExcelFile(DATA_FILE)

sheets = {sheet_name: xl_file.parse(sheet_name) 
          for sheet_name in xl_file.sheet_names}

data = sheets['main']

if DATA_FILE ==  "../../data-only-cat.xlsx":
    cat_fch = ['country', 'region', 'category', 'measure']
    data[cat_fch] = data[cat_fch].astype("category")
    data['comment-cluster'] = data['comment-cluster'].astype('str').astype('category')

else:
    data["country"] = data["country"].astype("category")
    data["region"] = data["region"].astype("category")


print('\n', data.info(), '\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74200 entries, 0 to 74199
# Columns: 126 entries, time_idx to negative-comment-embedding19
# dtypes: category(2), float64(40), int64(84)
# memory usage: 70.4 MB
#
#  None

# %%
data[data.country=='Canada'].plot(x='time_idx', y='confirmed-cases')
# Out:
# <AxesSubplot:xlabel='time_idx'>

# %%
data[data.country=='Canada']['confirmed-cases'].rolling(7).mean().fillna(0).round().astype('int').plot()
# Out:
# <AxesSubplot:>

# %%
for country in data.country.unique():
    data.loc[data.country == country, 'confirmed-cases'] =\
     data[data.country==country]['confirmed-cases'].rolling(7).\
                                                    mean().\
                                                    fillna(0).\
                                                    round().\
                                                    astype('int')

# %%
# Changing real values of measurements to zero and one categoris

def to_cat(x):
    
    x[x > 0] = "1"
    x[x == 0] = "0"
    
    return x


measures = [i for i in data.columns if 'comment' not in i and ("positive" in i or "negative" in i)]


data[measures] = data[measures].apply(to_cat).astype("category")

# Check if its working
i = 10
len(data[data[measures[i]] == "1"]) + len(data[data[measures[i]] == "0"]) == len(data)
# Out:
# True

# %%
# Removing countires with low number of new cases
avg_threshhold = 250

deleting_countries = []

for country in data.country.unique():
    case_avg = data[data.country == country]['confirmed-cases'].mean()
    if case_avg < avg_threshhold:
        deleting_countries.append(country)
        
print(f'Deleting {len(deleting_countries)} countries from {len(data.country.unique())} countries')

for country in deleting_countries:
    
    # Deleting those countries
    indices = data[data.country == country].index
    data = data.drop(indices)
# Out:
# Deleting 96 countries from 175 countries

# %%
# Remoivng all measures
# Removing negative and positive of the comments

# not_feature = ['time_idx', 'country', 'region', 'confirmed-cases']
# comments = [i for i in data.columns if 'comment' in i]
# com_names = [i[9:] for i in comments]
# data_only_com = data[comments].T.groupby(com_names).sum().T
# data_not_feature = data[not_feature].copy()
# data_not_feature[com_names[:20]] = data_only_com[com_names[:20]]
# data = data_not_feature
# data

# %%
measures = [i for i in data.columns if 'comment' not in i and ("positive" in i or "negative" in i)]
not_feature = ['time_idx', 'country', 'region', 'confirmed-cases']
comments = [i for i in data.columns if 'comment' in i]

# %%
# data = data.reset_index()
# data
data = data[not_feature + measures]
data
# Out:
#        time_idx    country    region  confirmed-cases  \
# 848           0    Algeria    Africa                0
# 849           1    Algeria    Africa                0
# 850           2    Algeria    Africa                0
# 851           3    Algeria    Africa                0
# 852           4    Algeria    Africa                0
# ...         ...        ...       ...              ...
# 72499       419  Venezuela  Americas              437
# 72500       420  Venezuela  Americas              447
# 72501       421  Venezuela  Americas              441
# 72502       422  Venezuela  Americas              454
# 72503       423  Venezuela  Americas              448
#
#       positive-Public health measures positive-Movement restrictions  \
# 848                                 0                              0
# 849                                 0                              0
# 850                                 0                              0
# 851                                 0                              0
# 852                                 0                              0
# ...                               ...                            ...
# 72499                               0                              0
# 72500                               0                              0
# 72501                               0                              0
# 72502                               0                              0
# 72503                               0                              0
#
#       positive-Governance and socio-economic measures  \
# 848                                                 0
# 849                                                 0
# 850                                                 0
# 851                                                 0
# 852                                                 0
# ...                                               ...
# 72499                                               0
# 72500                                               0
# 72501                                               0
# 72502                                               0
# 72503                                               0
#
#       positive-Social distancing positive-Lockdown  \
# 848                            0                 0
# 849                            0                 0
# 850                            0                 0
# 851                            0                 0
# 852                            0                 0
# ...                          ...               ...
# 72499                          0                 0
# 72500                          0                 0
# 72501                          0                 0
# 72502                          0                 0
# 72503                          0                 0
#
#       positive-Humanitarian exemption  ... negative-Testing policy  \
# 848                                 0  ...                       0
# 849                                 0  ...                       0
# 850                                 0  ...                       0
# 851                                 0  ...                       0
# 852                                 0  ...                       0
# ...                               ...  ...                     ...
# 72499                               0  ...                       0
# 72500                               0  ...                       0
# 72501                               0  ...                       0
# 72502                               0  ...                       0
# 72503                               0  ...                       0
#
#       negative-Amendments to funeral and burial regulations  \
# 848                                                    0
# 849                                                    0
# 850                                                    0
# 851                                                    0
# 852                                                    0
# ...                                                  ...
# 72499                                                  0
# 72500                                                  0
# 72501                                                  0
# 72502                                                  0
# 72503                                                  0
#
#       negative-Full lockdown  \
# 848                        0
# 849                        0
# 850                        0
# 851                        0
# 852                        0
# ...                      ...
# 72499                      0
# 72500                      0
# 72501                      0
# 72502                      0
# 72503                      0
#
#       negative-Lockdown of refugee/idp camps or other minorities  \
# 848                                                    0
# 849                                                    0
# 850                                                    0
# 851                                                    0
# 852                                                    0
# ...                                                  ...
# 72499                                                  0
# 72500                                                  0
# 72501                                                  0
# 72502                                                  0
# 72503                                                  0
#
#       negative-Additional health/documents requirements upon arrival  \
# 848                                                    0
# 849                                                    0
# 850                                                    0
# 851                                                    0
# 852                                                    0
# ...                                                  ...
# 72499                                                  0
# 72500                                                  0
# 72501                                                  0
# 72502                                                  0
# 72503                                                  0
#
#       negative-Mass population testing negative-Humanitarian exemptions  \
# 848                                  0                                0
# 849                                  0                                0
# 850                                  0                                0
# 851                                  0                                0
# 852                                  0                                0
# ...                                ...                              ...
# 72499                                0                                0
# 72500                                0                                0
# 72501                                0                                0
# 72502                                0                                0
# 72503                                0                                0
#
#       negative-Psychological assistance and medical social work  \
# 848                                                    0
# 849                                                    0
# 850                                                    0
# 851                                                    0
# 852                                                    0
# ...                                                  ...
# 72499                                                  0
# 72500                                                  0
# 72501                                                  0
# 72502                                                  0
# 72503                                                  0
#
#       negative-Complete border closure  \
# 848                                  0
# 849                                  0
# 850                                  0
# 851                                  0
# 852                                  0
# ...                                ...
# 72499                                0
# 72500                                0
# 72501                                0
# 72502                                0
# 72503                                0
#
#       negative-Obligatory medical tests not related to COVID-19
# 848                                                    0
# 849                                                    0
# 850                                                    0
# 851                                                    0
# 852                                                    0
# ...                                                  ...
# 72499                                                  0
# 72500                                                  0
# 72501                                                  0
# 72502                                                  0
# 72503                                                  0
#
# [33496 rows x 86 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33496 entries, 848 to 72503
# Data columns (total 86 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   time_idx                                                               33496 non-null  int64
#  1   country                                                                33496 non-null  category
#  2   region                                                                 33496 non-null  category
#  3   confirmed-cases                                                        33496 non-null  int64
#  4   positive-Public health measures                                        33496 non-null  category
#  5   positive-Movement restrictions                                         33496 non-null  category
#  6   positive-Governance and socio-economic measures                        33496 non-null  category
#  7   positive-Social distancing                                             33496 non-null  category
#  8   positive-Lockdown                                                      33496 non-null  category
#  9   positive-Humanitarian exemption                                        33496 non-null  category
#  10  positive-Awareness campaigns                                           33496 non-null  category
#  11  positive-Health screenings in airports and border crossings            33496 non-null  category
#  12  positive-International flights suspension                              33496 non-null  category
#  13  positive-Border checks                                                 33496 non-null  category
#  14  positive-Strengthening the public health system                        33496 non-null  category
#  15  positive-Isolation and quarantine policies                             33496 non-null  category
#  16  positive-Emergency administrative structures activated or established  33496 non-null  category
#  17  positive-Surveillance and monitoring                                   33496 non-null  category
#  18  positive-Other public health measures enforced                         33496 non-null  category
#  19  positive-Border closure                                                33496 non-null  category
#  20  positive-General recommendations                                       33496 non-null  category
#  21  positive-State of emergency declared                                   33496 non-null  category
#  22  positive-Domestic travel restrictions                                  33496 non-null  category
#  23  positive-Limit public gatherings                                       33496 non-null  category
#  24  positive-Limit product imports/exports                                 33496 non-null  category
#  25  positive-Schools closure                                               33496 non-null  category
#  26  positive-Partial lockdown                                              33496 non-null  category
#  27  positive-Changes in prison-related policies                            33496 non-null  category
#  28  positive-Closure of businesses and public services                     33496 non-null  category
#  29  positive-Checkpoints within the country                                33496 non-null  category
#  30  positive-Economic measures                                             33496 non-null  category
#  31  positive-Military deployment                                           33496 non-null  category
#  32  positive-Curfews                                                       33496 non-null  category
#  33  positive-Visa restrictions                                             33496 non-null  category
#  34  positive-Requirement to wear protective gear in public                 33496 non-null  category
#  35  positive-Testing policy                                                33496 non-null  category
#  36  positive-Amendments to funeral and burial regulations                  33496 non-null  category
#  37  positive-Full lockdown                                                 33496 non-null  category
#  38  positive-Lockdown of refugee/idp camps or other minorities             33496 non-null  category
#  39  positive-Additional health/documents requirements upon arrival         33496 non-null  category
#  40  positive-Mass population testing                                       33496 non-null  category
#  41  positive-Humanitarian exemptions                                       33496 non-null  category
#  42  positive-Psychological assistance and medical social work              33496 non-null  category
#  43  positive-Complete border closure                                       33496 non-null  category
#  44  positive-Obligatory medical tests not related to COVID-19              33496 non-null  category
#  45  negative-Public health measures                                        33496 non-null  category
#  46  negative-Movement restrictions                                         33496 non-null  category
#  47  negative-Governance and socio-economic measures                        33496 non-null  category
#  48  negative-Social distancing                                             33496 non-null  category
#  49  negative-Lockdown                                                      33496 non-null  category
#  50  negative-Humanitarian exemption                                        33496 non-null  category
#  51  negative-Awareness campaigns                                           33496 non-null  category
#  52  negative-Health screenings in airports and border crossings            33496 non-null  category
#  53  negative-International flights suspension                              33496 non-null  category
#  54  negative-Border checks                                                 33496 non-null  category
#  55  negative-Strengthening the public health system                        33496 non-null  category
#  56  negative-Isolation and quarantine policies                             33496 non-null  category
#  57  negative-Emergency administrative structures activated or established  33496 non-null  category
#  58  negative-Surveillance and monitoring                                   33496 non-null  category
#  59  negative-Other public health measures enforced                         33496 non-null  category
#  60  negative-Border closure                                                33496 non-null  category
#  61  negative-General recommendations                                       33496 non-null  category
#  62  negative-State of emergency declared                                   33496 non-null  category
#  63  negative-Domestic travel restrictions                                  33496 non-null  category
#  64  negative-Limit public gatherings                                       33496 non-null  category
#  65  negative-Limit product imports/exports                                 33496 non-null  category
#  66  negative-Schools closure                                               33496 non-null  category
#  67  negative-Partial lockdown                                              33496 non-null  category
#  68  negative-Changes in prison-related policies                            33496 non-null  category
#  69  negative-Closure of businesses and public services                     33496 non-null  category
#  70  negative-Checkpoints within the country                                33496 non-null  category
#  71  negative-Economic measures                                             33496 non-null  category
#  72  negative-Military deployment                                           33496 non-null  category
#  73  negative-Curfews                                                       33496 non-null  category
#  74  negative-Visa restrictions                                             33496 non-null  category
#  75  negative-Requirement to wear protective gear in public                 33496 non-null  category
#  76  negative-Testing policy                                                33496 non-null  category
#  77  negative-Amendments to funeral and burial regulations                  33496 non-null  category
#  78  negative-Full lockdown                                                 33496 non-null  category
#  79  negative-Lockdown of refugee/idp camps or other minorities             33496 non-null  category
#  80  negative-Additional health/documents requirements upon arrival         33496 non-null  category
#  81  negative-Mass population testing                                       33496 non-null  category
#  82  negative-Humanitarian exemptions                                       33496 non-null  category
#  83  negative-Psychological assistance and medical social work              33496 non-null  category
#  84  negative-Complete border closure                                       33496 non-null  category
#  85  negative-Obligatory medical tests not related to COVID-19              33496 non-null  category
# dtypes: category(84), int64(2)
# memory usage: 3.5 MB

# %%
training_cutoff = data['time_idx'].max() - MAX_PREDICTION_LENGTH - 30


training = TimeSeriesDataSet(
    data[lambda x: x.time_idx <= training_cutoff],
    time_idx='time_idx',
    target='confirmed-cases',
    group_ids=['country'],
    weight=None,
    min_encoder_length=MAX_ENCODER_LENGTH,
    max_encoder_length=MAX_ENCODER_LENGTH,
    min_prediction_length=MAX_PREDICTION_LENGTH,
    max_prediction_length=MAX_PREDICTION_LENGTH,
    static_categoricals=['country', 'region'],
    time_varying_unknown_categoricals = measures,
    time_varying_known_reals=['time_idx'],
    time_varying_unknown_reals = ['confirmed-cases'], #com_names[:20] +
    
    target_normalizer=GroupNormalizer(
        groups=["country"], #transformation="softplus"
    ),
    add_relative_time_idx=True,
    add_target_scales=True,
    add_encoder_length=True
)

validation = TimeSeriesDataSet.from_dataset(
    training, 
    data[lambda x: x.time_idx <= training_cutoff + MAX_PREDICTION_LENGTH],
    predict=True, stop_randomization=True
)

# %%
train_dataloader = training.to_dataloader(
    train=True, 
    batch_size=BATCH_SIZE,
    num_workers=0                                     
)

val_dataloader = validation.to_dataloader(
    train=False,
    batch_size=BATCH_SIZE*10,
    num_workers=0
)

# %%
early_stop_callback = EarlyStopping(
    monitor='val_loss',
    min_delta=1e-4,
    patience=10,
    verbose=False,
    mode='min'
)

lr_logger = LearningRateMonitor()
logger = TensorBoardLogger('lightning_logs')

# %% [markdown]
# ### Finding Optimal Learning Rate

# %%
# import tensorflow as tf
# import tensorboard as tb
# tf.io.gfile = tb.compat.tensorflow_stub.io.gfile
# create trainer
trainer = pl.Trainer(
    max_epochs=1000,
    gpus=[0],  # train on CPU, use gpus = [0] to run on GPU
    gradient_clip_val=0.1,
    weights_summary='top',
    limit_train_batches=30,  # running validation every 30 batches
    # fast_dev_run=True,  # comment in to quickly check for bugs
    callbacks=[lr_logger, early_stop_callback],
    logger=logger,
)
# initialise model
tft = TemporalFusionTransformer.from_dataset(
    training,
    learning_rate= 8e-04,
    hidden_size=32,  # biggest influence network size
    attention_head_size=1,
    dropout=0.1,
    hidden_continuous_size=16 ,
    output_size=7,  # QuantileLoss has 7 quantiles by default
    loss=QuantileLoss(),
    log_interval=10,  # log example every 10 batches
    reduce_on_plateau_patience=4,  # reduce learning automatically
)
# tft.size() # 29.6k parameters in model
# # # fit network
trainer.fit(
    tft,
    train_dataloader=train_dataloader,
    val_dataloaders=val_dataloader
)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2]
#
#    | Name                               | Type                            | Params
# ----------------------------------------------------------------------------------------
# 0  | loss                               | QuantileLoss                    | 0
# 1  | logging_metrics                    | ModuleList                      | 0
# 2  | input_embeddings                   | MultiEmbedding                  | 1.6 K
# 3  | prescalers                         | ModuleDict                      | 192
# 4  | static_variable_selection          | VariableSelectionNetwork        | 6.1 K
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 25.7 K
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 3.8 K
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 4.3 K
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 4.3 K
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 4.3 K
# 10 | static_context_enrichment          | GatedResidualNetwork            | 4.3 K
# 11 | lstm_encoder                       | LSTM                            | 8.4 K
# 12 | lstm_decoder                       | LSTM                            | 8.4 K
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 2.1 K
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 64
# 15 | static_enrichment                  | GatedResidualNetwork            | 5.3 K
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 4.2 K
# 17 | post_attn_gate_norm                | GateAddNorm                     | 2.2 K
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 4.3 K
# 19 | pre_output_gate_norm               | GateAddNorm                     | 2.2 K
# 20 | output_layer                       | Linear                          | 231
# ----------------------------------------------------------------------------------------
# 91.7 K    Trainable params
# 0         Non-trainable params
# 91.7 K    Total params
# 0.367     Total estimated model params size (MB)
# /home/m25dehgh/anaconda3/envs/pyforecast/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:68: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# HBox(children=(HTML(value='Validation sanity check'), FloatProgress(value=1.0, bar_style='info', layout=Layout…
# /home/m25dehgh/anaconda3/envs/pyforecast/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:68: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 24 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# HBox(children=(HTML(value='Training'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), max…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# HBox(children=(HTML(value='Validating'), FloatProgress(value=1.0, bar_style='info', layout=Layout(flex='2'), m…
# 1

# %%
# load the best model according to the validation loss
# (given that we use early stopping, this is not necessarily the last epoch)
best_model_path = trainer.checkpoint_callback.best_model_path
best_tft = TemporalFusionTransformer.load_from_checkpoint(best_model_path)
# best_tft

# trainer.fit(
#     best_tft,
#     train_dataloader=train_dataloader,
#     val_dataloaders=val_dataloader
# )
# type(best_tft)

# %%
data_val = data.copy()

# %%
avg_threshhold = 1350

deleting_countries = []

for country in data_val.country.unique():
    case_avg = data_val[data_val.country == country]['confirmed-cases'].mean()
    if case_avg < avg_threshhold:
        deleting_countries.append(country)
        
print(f'Deleting {len(deleting_countries)} countries from {len(data_val.country.unique())} countries')

for country in deleting_countries:
    
    # Deleting those countries
    indices = data_val[data_val.country == country].index
    data_val = data_val.drop(indices)
# Out:
# Deleting 49 countries from 79 countries

# %%
len(data_val.country.unique())
# Out:
# 30

# %%
validation = TimeSeriesDataSet.from_dataset(
    training, 
    data_val[lambda x: x.time_idx <= training_cutoff + MAX_PREDICTION_LENGTH],
    predict=True, stop_randomization=True
)

val_dataloader = validation.to_dataloader(
    train=False,
    batch_size=BATCH_SIZE*10,
    num_workers=0
)

# %%
from pytorch_forecasting.metrics import MAPE

metric = MAPE()

# best_tft = tft
actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
predictions = best_tft.predict(val_dataloader)
# (actuals - predictions).abs().mean()
metric.loss(predictions, actuals).mean()
# Out:
# tensor(0.2487)

# %%
raw_predictions, x = best_tft.predict(val_dataloader, mode="raw", return_x=True)

# %%
for idx in range(10):  # plot 10 examples
    best_tft.plot_prediction(x, raw_predictions, idx=idx, add_loss_to_title=True);

# %%
predictions, x = best_tft.predict(val_dataloader, return_x=True)
predictions_vs_actuals = best_tft.calculate_prediction_actual_by_variable(x, predictions)
best_tft.plot_prediction_actual_by_variable(predictions_vs_actuals);
# Out:
# /home/m25dehgh/anaconda3/envs/pyforecast/lib/python3.8/site-packages/pytorch_forecasting/models/base_model.py:1370: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(**kwargs)

# %%
interpretation = best_tft.interpret_output(raw_predictions, reduction="sum")
best_tft.plot_interpretation(interpretation)
# Out:
# {'attention': <Figure size 432x288 with 1 Axes>,
#  'static_variables': <Figure size 504x234 with 1 Axes>,
#  'encoder_variables': <Figure size 504x1674 with 1 Axes>,
#  'decoder_variables': <Figure size 504x180 with 1 Axes>}
